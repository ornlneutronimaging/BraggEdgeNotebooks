# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Method

# %% [markdown]
# **Step1: **
#
# This notebook will load the vacuum_furnace (time vs Temperature) ascii file
#
# **Step2: **
#
# Display the temperature vs time to facilitate binning selection
#
# **Step3: **
#
# Using binning defined, make list of files to bin together
#
# **Step4: **
#
# Output that binning selection into another ascii file
#
# ex: my_binning.txt
#
#     from                        to                    Temperature
#     9/2/2015 4:17:22 PM     9/2/210 4:24:33 PM            33
#     9/2/2015 4:24:33 PM     9/2/210 4:28:33 PM            50
#     9/2/2015 4:28:33 PM     9/2/210 4:33:33 PM            70
#     ....

# %% [markdown]
# ## Load file

# %%
root_folder = '/Volumes/My Book Thunderbolt Duo/IPTS/BraggEdge/SNAP/SNAP_August_September_2015/'
output_file = root_folder + 'temperature_spectrum.csv'

# %%
import time
import datetime
my_date = '9/2/2015 4:17:22 PM'
my_time = time.mktime(datetime.datetime.strptime(my_date, '%m/%d/%Y %I:%M:%S %p').timetuple())
print(my_time)
# Out:
# 1441225042.0

# %%
import time
import datetime
def dateparse (date_time):
    return time.mktime(datetime.datetime.strptime(date_time, '%m/%d/%Y %I:%M:%S %p').timetuple())

# %%
#df = pd.read_csv(output_file, header=None, names=['time', 'temperature (C)'])
df = pd.read_csv(output_file, parse_dates=True, date_parser=dateparse, header=None)

# %%
df.head()
# Out:
#                       0     1
# 0  9/2/2015  4:17:22 PM  22.0
# 1  9/2/2015  4:17:44 PM  22.0
# 2  9/2/2015  4:18:06 PM  22.0
# 3  9/2/2015  4:18:27 PM  22.0
# 4  9/2/2015  4:18:49 PM  22.0

# %% [markdown]
# ## Display data

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
df.head()
# Out:
#                    time  temperature (C)
# 0  9/2/2015  4:17:22 PM             22.0
# 1  9/2/2015  4:17:44 PM             22.0
# 2  9/2/2015  4:18:06 PM             22.0
# 3  9/2/2015  4:18:27 PM             22.0
# 4  9/2/2015  4:18:49 PM             22.0

# %%
# Out:
# str
